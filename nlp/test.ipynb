# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
type(text1)
# Out:
# nltk.text.Text

# %%
text1.concordance('monstrous')
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %%
# %matplotlib inline
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %%
text1.index('a')
# Out:
# 13

# %%
nltk.book.FreqDist
# Out:
# type

# %%
from nltk.util import bigrams

# %%
from nltk.util import trigrams

# %%
list(trigrams(text1))
# Out:
# [('[', 'Moby', 'Dick'),
#  ('Moby', 'Dick', 'by'),
#  ('Dick', 'by', 'Herman'),
#  ('by', 'Herman', 'Melville'),
#  ('Herman', 'Melville', '1851'),
#  ('Melville', '1851', ']'),
#  ('1851', ']', 'ETYMOLOGY'),
#  (']', 'ETYMOLOGY', '.'),
#  ('ETYMOLOGY', '.', '('),
#  ('.', '(', 'Supplied'),
#  ('(', 'Supplied', 'by'),
#  ('Supplied', 'by', 'a'),
#  ('by', 'a', 'Late'),
#  ('a', 'Late', 'Consumptive'),
#  ('Late', 'Consumptive', 'Usher'),
#  ('Consumptive', 'Usher', 'to'),
#  ('Usher', 'to', 'a'),
#  ('to', 'a', 'Grammar'),
#  ('a', 'Grammar', 'School'),
#  ('Grammar', 'School', ')'),
#  ('School', ')', 'The'),
#  (')', 'The', 'pale'),
#  ('The', 'pale', 'Usher'),
#  ('pale', 'Usher', '--'),
#  ('Usher', '--', 'threadbare'),
#  ('--', 'threadbare', 'in'),
#  ('threadbare', 'in', 'coat'),
#  ('in', 'coat', ','),
#  ('coat', ',', 'heart'),
#  (',', 'heart', ','),
#  ('heart', ',', 'body'),
#  (',', 'body', ','),
#  ('body', ',', 'and'),
#  (',', 'and', 'brain'),
#  ('and', 'brain', ';'),
#  ('brain', ';', 'I'),
#  (';', 'I', 'see'),
#  ('I', 'see', 'him'),
#  ('see', 'him', 'now'),
#  ('him', 'now', '.'),
#  ('now', '.', 'He'),
#  ('.', 'He', 'was'),
#  ('He', 'was', 'ever'),
#  ('was', 'ever', 'dusting'),
#  ('ever', 'dusting', 'his'),
#  ('dusting', 'his', 'old'),
#  ('his', 'old', 'lexicons'),
#  ('old', 'lexicons', 'and'),
#  ('lexicons', 'and', 'grammars'),
#  ('and', 'grammars', ','),
#  ('grammars', ',', 'with'),
#  (',', 'with', 'a'),
#  ('with', 'a', 'queer'),
#  ('a', 'queer', 'handkerchief'),
#  ('queer', 'handkerchief', ','),
#  ('handkerchief', ',', 'mockingly'),
#  (',', 'mockingly', 'embellished'),
#  ('mockingly', 'embellished', 'with'),
#  ('embellished', 'with', 'all'),
#  ('with', 'all', 'the'),
#  ('all', 'the', 'gay'),
#  ('the', 'gay', 'flags'),
#  ('gay', 'flags', 'of'),
#  ('flags', 'of', 'all'),
#  ('of', 'all', 'the'),
#  ('all', 'the', 'known'),
#  ('the', 'known', 'nations'),
#  ('known', 'nations', 'of'),
#  ('nations', 'of', 'the'),
#  ('of', 'the', 'world'),
#  ('the', 'world', '.'),
#  ('world', '.', 'He'),
#  ('.', 'He', 'loved'),
#  ('He', 'loved', 'to'),
#  ('loved', 'to', 'dust'),
#  ('to', 'dust', 'his'),
#  ('dust', 'his', 'old'),
#  ('his', 'old', 'grammars'),
#  ('old', 'grammars', ';'),
#  ('grammars', ';', 'it'),
#  (';', 'it', 'somehow'),
#  ('it', 'somehow', 'mildly'),
#  ('somehow', 'mildly', 'reminded'),
#  ('mildly', 'reminded', 'him'),
#  ('reminded', 'him', 'of'),
#  ('him', 'of', 'his'),
#  ('of', 'his', 'mortality'),
#  ('his', 'mortality', '.'),
#  ('mortality', '.', '"'),
#  ('.', '"', 'While'),
#  ('"', 'While', 'you'),
#  ('While', 'you', 'take'),
#  ('you', 'take', 'in'),
#  ('take', 'in', 'hand'),
#  ('in', 'hand', 'to'),
#  ('hand', 'to', 'school'),
#  ('to', 'school', 'others'),
#  ('school', 'others', ','),
#  ('others', ',', 'and'),
#  (',', 'and', 'to'),
#  ('and', 'to', 'teach'),
#  ('to', 'teach', 'them'),
#  ('teach', 'them', 'by'),
#  ('them', 'by', 'what'),
#  ('by', 'what', 'name'),
#  ('what', 'name', 'a'),
#  ('name', 'a', 'whale'),
#  ('a', 'whale', '-'),
#  ('whale', '-', 'fish'),
#  ('-', 'fish', 'is'),
#  ('fish', 'is', 'to'),
#  ('is', 'to', 'be'),
#  ('to', 'be', 'called'),
#  ('be', 'called', 'in'),
#  ('called', 'in', 'our'),
#  ('in', 'our', 'tongue'),
#  ('our', 'tongue', 'leaving'),
#  ('tongue', 'leaving', 'out'),
#  ('leaving', 'out', ','),
#  ('out', ',', 'through'),
#  (',', 'through', 'ignorance'),
#  ('through', 'ignorance', ','),
#  ('ignorance', ',', 'the'),
#  (',', 'the', 'letter'),
#  ('the', 'letter', 'H'),
#  ('letter', 'H', ','),
#  ('H', ',', 'which'),
#  (',', 'which', 'almost'),
#  ('which', 'almost', 'alone'),
#  ('almost', 'alone', 'maketh'),
#  ('alone', 'maketh', 'the'),
#  ('maketh', 'the', 'signification'),
#  ('the', 'signification', 'of'),
#  ('signification', 'of', 'the'),
#  ('of', 'the', 'word'),
#  ('the', 'word', ','),
#  ('word', ',', 'you'),
#  (',', 'you', 'deliver'),
#  ('you', 'deliver', 'that'),
#  ('deliver', 'that', 'which'),
#  ('that', 'which', 'is'),
#  ('which', 'is', 'not'),
#  ('is', 'not', 'true'),
#  ('not', 'true', '."'),
#  ('true', '."', '--'),
#  ('."', '--', 'HACKLUYT'),
#  ('--', 'HACKLUYT', '"'),
#  ('HACKLUYT', '"', 'WHALE'),
#  ('"', 'WHALE', '.'),
#  ('WHALE', '.', '...'),
#  ('.', '...', 'Sw'),
#  ('...', 'Sw', '.'),
#  ('Sw', '.', 'and'),
#  ('.', 'and', 'Dan'),
#  ('and', 'Dan', '.'),
#  ('Dan', '.', 'HVAL'),
#  ('.', 'HVAL', '.'),
#  ('HVAL', '.', 'This'),
#  ('.', 'This', 'animal'),
#  ('This', 'animal', 'is'),
#  ('animal', 'is', 'named'),
#  ('is', 'named', 'from'),
#  ('named', 'from', 'roundness'),
#  ('from', 'roundness', 'or'),
#  ('roundness', 'or', 'rolling'),
#  ('or', 'rolling', ';'),
#  ('rolling', ';', 'for'),
#  (';', 'for', 'in'),
#  ('for', 'in', 'Dan'),
#  ('in', 'Dan', '.'),
#  ('Dan', '.', 'HVALT'),
#  ('.', 'HVALT', 'is'),
#  ('HVALT', 'is', 'arched'),
#  ('is', 'arched', 'or'),
#  ('arched', 'or', 'vaulted'),
#  ('or', 'vaulted', '."'),
#  ('vaulted', '."', '--'),
#  ('."', '--', 'WEBSTER'),
#  ('--', 'WEBSTER', "'"),
#  ('WEBSTER', "'", 'S'),
#  ("'", 'S', 'DICTIONARY'),
#  ('S', 'DICTIONARY', '"'),
#  ('DICTIONARY', '"', 'WHALE'),
#  ('"', 'WHALE', '.'),
#  ('WHALE', '.', '...'),
#  ('.', '...', 'It'),
#  ('...', 'It', 'is'),
#  ('It', 'is', 'more'),
#  ('is', 'more', 'immediately'),
#  ('more', 'immediately', 'from'),
#  ('immediately', 'from', 'the'),
#  ('from', 'the', 'Dut'),
#  ('the', 'Dut', '.'),
#  ('Dut', '.', 'and'),
#  ('.', 'and', 'Ger'),
#  ('and', 'Ger', '.'),
#  ('Ger', '.', 'WALLEN'),
#  ('.', 'WALLEN', ';'),
#  ('WALLEN', ';', 'A'),
#  (';', 'A', '.'),
#  ('A', '.', 'S'),
#  ('.', 'S', '.'),
#  ('S', '.', 'WALW'),
#  ('.', 'WALW', '-'),
#  ('WALW', '-', 'IAN'),
#  ('-', 'IAN', ','),
#  ('IAN', ',', 'to'),
#  (',', 'to', 'roll'),
#  ('to', 'roll', ','),
#  ('roll', ',', 'to'),
#  (',', 'to', 'wallow'),
#  ('to', 'wallow', '."'),
#  ('wallow', '."', '--'),
#  ('."', '--', 'RICHARDSON'),
#  ('--', 'RICHARDSON', "'"),
#  ('RICHARDSON', "'", 'S'),
#  ("'", 'S', 'DICTIONARY'),
#  ('S', 'DICTIONARY', 'KETOS'),
#  ('DICTIONARY', 'KETOS', ','),
#  ('KETOS', ',', 'GREEK'),
#  (',', 'GREEK', '.'),
#  ('GREEK', '.', 'CETUS'),
#  ('.', 'CETUS', ','),
#  ('CETUS', ',', 'LATIN'),
#  (',', 'LATIN', '.'),
#  ('LATIN', '.', 'WHOEL'),
#  ('.', 'WHOEL', ','),
#  ('WHOEL', ',', 'ANGLO'),
#  (',', 'ANGLO', '-'),
#  ('ANGLO', '-', 'SAXON'),
#  ('-', 'SAXON', '.'),
#  ('SAXON', '.', 'HVALT'),
#  ('.', 'HVALT', ','),
#  ('HVALT', ',', 'DANISH'),
#  (',', 'DANISH', '.'),
#  ('DANISH', '.', 'WAL'),
#  ('.', 'WAL', ','),
#  ('WAL', ',', 'DUTCH'),
#  (',', 'DUTCH', '.'),
#  ('DUTCH', '.', 'HWAL'),
#  ('.', 'HWAL', ','),
#  ('HWAL', ',', 'SWEDISH'),
#  (',', 'SWEDISH', '.'),
#  ('SWEDISH', '.', 'WHALE'),
#  ('.', 'WHALE', ','),
#  ('WHALE', ',', 'ICELANDIC'),
#  (',', 'ICELANDIC', '.'),
#  ('ICELANDIC', '.', 'WHALE'),
#  ('.', 'WHALE', ','),
#  ('WHALE', ',', 'ENGLISH'),
#  (',', 'ENGLISH', '.'),
#  ('ENGLISH', '.', 'BALEINE'),
#  ('.', 'BALEINE', ','),
#  ('BALEINE', ',', 'FRENCH'),
#  (',', 'FRENCH', '.'),
#  ('FRENCH', '.', 'BALLENA'),
#  ('.', 'BALLENA', ','),
#  ('BALLENA', ',', 'SPANISH'),
#  (',', 'SPANISH', '.'),
#  ('SPANISH', '.', 'PEKEE'),
#  ('.', 'PEKEE', '-'),
#  ('PEKEE', '-', 'NUEE'),
#  ('-', 'NUEE', '-'),
#  ('NUEE', '-', 'NUEE'),
#  ('-', 'NUEE', ','),
#  ('NUEE', ',', 'FEGEE'),
#  (',', 'FEGEE', '.'),
#  ('FEGEE', '.', 'PEKEE'),
#  ('.', 'PEKEE', '-'),
#  ('PEKEE', '-', 'NUEE'),
#  ('-', 'NUEE', '-'),
#  ('NUEE', '-', 'NUEE'),
#  ('-', 'NUEE', ','),
#  ('NUEE', ',', 'ERROMANGOAN'),
#  (',', 'ERROMANGOAN', '.'),
#  ('ERROMANGOAN', '.', 'EXTRACTS'),
#  ('.', 'EXTRACTS', '('),
#  ('EXTRACTS', '(', 'Supplied'),
#  ('(', 'Supplied', 'by'),
#  ('Supplied', 'by', 'a'),
#  ('by', 'a', 'Sub'),
#  ('a', 'Sub', '-'),
#  ('Sub', '-', 'Sub'),
#  ('-', 'Sub', '-'),
#  ('Sub', '-', 'Librarian'),
#  ('-', 'Librarian', ').'),
#  ('Librarian', ').', 'It'),
#  (').', 'It', 'will'),
#  ('It', 'will', 'be'),
#  ('will', 'be', 'seen'),
#  ('be', 'seen', 'that'),
#  ('seen', 'that', 'this'),
#  ('that', 'this', 'mere'),
#  ('this', 'mere', 'painstaking'),
#  ('mere', 'painstaking', 'burrower'),
#  ('painstaking', 'burrower', 'and'),
#  ('burrower', 'and', 'grub'),
#  ('and', 'grub', '-'),
#  ('grub', '-', 'worm'),
#  ('-', 'worm', 'of'),
#  ('worm', 'of', 'a'),
#  ('of', 'a', 'poor'),
#  ('a', 'poor', 'devil'),
#  ('poor', 'devil', 'of'),
#  ('devil', 'of', 'a'),
#  ('of', 'a', 'Sub'),
#  ('a', 'Sub', '-'),
#  ('Sub', '-', 'Sub'),
#  ('-', 'Sub', 'appears'),
#  ('Sub', 'appears', 'to'),
#  ('appears', 'to', 'have'),
#  ('to', 'have', 'gone'),
#  ('have', 'gone', 'through'),
#  ('gone', 'through', 'the'),
#  ('through', 'the', 'long'),
#  ('the', 'long', 'Vaticans'),
#  ('long', 'Vaticans', 'and'),
#  ('Vaticans', 'and', 'street'),
#  ('and', 'street', '-'),
#  ('street', '-', 'stalls'),
#  ('-', 'stalls', 'of'),
#  ('stalls', 'of', 'the'),
#  ('of', 'the', 'earth'),
#  ('the', 'earth', ','),
#  ('earth', ',', 'picking'),
#  (',', 'picking', 'up'),
#  ('picking', 'up', 'whatever'),
#  ('up', 'whatever', 'random'),
#  ('whatever', 'random', 'allusions'),
#  ('random', 'allusions', 'to'),
#  ('allusions', 'to', 'whales'),
#  ('to', 'whales', 'he'),
#  ('whales', 'he', 'could'),
#  ('he', 'could', 'anyways'),
#  ('could', 'anyways', 'find'),
#  ('anyways', 'find', 'in'),
#  ('find', 'in', 'any'),
#  ('in', 'any', 'book'),
#  ('any', 'book', 'whatsoever'),
#  ('book', 'whatsoever', ','),
#  ('whatsoever', ',', 'sacred'),
#  (',', 'sacred', 'or'),
#  ('sacred', 'or', 'profane'),
#  ('or', 'profane', '.'),
#  ('profane', '.', 'Therefore'),
#  ('.', 'Therefore', 'you'),
#  ('Therefore', 'you', 'must'),
#  ('you', 'must', 'not'),
#  ('must', 'not', ','),
#  ('not', ',', 'in'),
#  (',', 'in', 'every'),
#  ('in', 'every', 'case'),
#  ('every', 'case', 'at'),
#  ('case', 'at', 'least'),
#  ('at', 'least', ','),
#  ('least', ',', 'take'),
#  (',', 'take', 'the'),
#  ('take', 'the', 'higgledy'),
#  ('the', 'higgledy', '-'),
#  ('higgledy', '-', 'piggledy'),
#  ('-', 'piggledy', 'whale'),
#  ('piggledy', 'whale', 'statements'),
#  ('whale', 'statements', ','),
#  ('statements', ',', 'however'),
#  (',', 'however', 'authentic'),
#  ('however', 'authentic', ','),
#  ('authentic', ',', 'in'),
#  (',', 'in', 'these'),
#  ('in', 'these', 'extracts'),
#  ('these', 'extracts', ','),
#  ('extracts', ',', 'for'),
#  (',', 'for', 'veritable'),
#  ('for', 'veritable', 'gospel'),
#  ('veritable', 'gospel', 'cetology'),
#  ('gospel', 'cetology', '.'),
#  ('cetology', '.', 'Far'),
#  ('.', 'Far', 'from'),
#  ('Far', 'from', 'it'),
#  ('from', 'it', '.'),
#  ('it', '.', 'As'),
#  ('.', 'As', 'touching'),
#  ('As', 'touching', 'the'),
#  ('touching', 'the', 'ancient'),
#  ('the', 'ancient', 'authors'),
#  ('ancient', 'authors', 'generally'),
#  ('authors', 'generally', ','),
#  ('generally', ',', 'as'),
#  (',', 'as', 'well'),
#  ('as', 'well', 'as'),
#  ('well', 'as', 'the'),
#  ('as', 'the', 'poets'),
#  ('the', 'poets', 'here'),
#  ('poets', 'here', 'appearing'),
#  ('here', 'appearing', ','),
#  ('appearing', ',', 'these'),
#  (',', 'these', 'extracts'),
#  ('these', 'extracts', 'are'),
#  ('extracts', 'are', 'solely'),
#  ('are', 'solely', 'valuable'),
#  ('solely', 'valuable', 'or'),
#  ('valuable', 'or', 'entertaining'),
#  ('or', 'entertaining', ','),
#  ('entertaining', ',', 'as'),
#  (',', 'as', 'affording'),
#  ('as', 'affording', 'a'),
#  ('affording', 'a', 'glancing'),
#  ('a', 'glancing', 'bird'),
#  ('glancing', 'bird', "'"),
#  ('bird', "'", 's'),
#  ("'", 's', 'eye'),
#  ('s', 'eye', 'view'),
#  ('eye', 'view', 'of'),
#  ('view', 'of', 'what'),
#  ('of', 'what', 'has'),
#  ('what', 'has', 'been'),
#  ('has', 'been', 'promiscuously'),
#  ('been', 'promiscuously', 'said'),
#  ('promiscuously', 'said', ','),
#  ('said', ',', 'thought'),
#  (',', 'thought', ','),
#  ('thought', ',', 'fancied'),
#  (',', 'fancied', ','),
#  ('fancied', ',', 'and'),
#  (',', 'and', 'sung'),
#  ('and', 'sung', 'of'),
#  ('sung', 'of', 'Leviathan'),
#  ('of', 'Leviathan', ','),
#  ('Leviathan', ',', 'by'),
#  (',', 'by', 'many'),
#  ('by', 'many', 'nations'),
#  ('many', 'nations', 'and'),
#  ('nations', 'and', 'generations'),
#  ('and', 'generations', ','),
#  ('generations', ',', 'including'),
#  (',', 'including', 'our'),
#  ('including', 'our', 'own'),
#  ('our', 'own', '.'),
#  ('own', '.', 'So'),
#  ('.', 'So', 'fare'),
#  ('So', 'fare', 'thee'),
#  ('fare', 'thee', 'well'),
#  ('thee', 'well', ','),
#  ('well', ',', 'poor'),
#  (',', 'poor', 'devil'),
#  ('poor', 'devil', 'of'),
#  ('devil', 'of', 'a'),
#  ('of', 'a', 'Sub'),
#  ('a', 'Sub', '-'),
#  ('Sub', '-', 'Sub'),
#  ('-', 'Sub', ','),
#  ('Sub', ',', 'whose'),
#  (',', 'whose', 'commentator'),
#  ('whose', 'commentator', 'I'),
#  ('commentator', 'I', 'am'),
#  ('I', 'am', '.'),
#  ('am', '.', 'Thou'),
#  ('.', 'Thou', 'belongest'),
#  ('Thou', 'belongest', 'to'),
#  ('belongest', 'to', 'that'),
#  ('to', 'that', 'hopeless'),
#  ('that', 'hopeless', ','),
#  ('hopeless', ',', 'sallow'),
#  (',', 'sallow', 'tribe'),
#  ('sallow', 'tribe', 'which'),
#  ('tribe', 'which', 'no'),
#  ('which', 'no', 'wine'),
#  ('no', 'wine', 'of'),
#  ('wine', 'of', 'this'),
#  ('of', 'this', 'world'),
#  ('this', 'world', 'will'),
#  ('world', 'will', 'ever'),
#  ('will', 'ever', 'warm'),
#  ('ever', 'warm', ';'),
#  ('warm', ';', 'and'),
#  (';', 'and', 'for'),
#  ('and', 'for', 'whom'),
#  ('for', 'whom', 'even'),
#  ('whom', 'even', 'Pale'),
#  ('even', 'Pale', 'Sherry'),
#  ('Pale', 'Sherry', 'would'),
#  ('Sherry', 'would', 'be'),
#  ('would', 'be', 'too'),
#  ('be', 'too', 'rosy'),
#  ('too', 'rosy', '-'),
#  ('rosy', '-', 'strong'),
#  ('-', 'strong', ';'),
#  ('strong', ';', 'but'),
#  (';', 'but', 'with'),
#  ('but', 'with', 'whom'),
#  ('with', 'whom', 'one'),
#  ('whom', 'one', 'sometimes'),
#  ('one', 'sometimes', 'loves'),
#  ('sometimes', 'loves', 'to'),
#  ('loves', 'to', 'sit'),
#  ('to', 'sit', ','),
#  ('sit', ',', 'and'),
#  (',', 'and', 'feel'),
#  ('and', 'feel', 'poor'),
#  ('feel', 'poor', '-'),
#  ('poor', '-', 'devilish'),
#  ('-', 'devilish', ','),
#  ('devilish', ',', 'too'),
#  (',', 'too', ';'),
#  ('too', ';', 'and'),
#  (';', 'and', 'grow'),
#  ('and', 'grow', 'convivial'),
#  ('grow', 'convivial', 'upon'),
#  ('convivial', 'upon', 'tears'),
#  ('upon', 'tears', ';'),
#  ('tears', ';', 'and'),
#  (';', 'and', 'say'),
#  ('and', 'say', 'to'),
#  ('say', 'to', 'them'),
#  ('to', 'them', 'bluntly'),
#  ('them', 'bluntly', ','),
#  ('bluntly', ',', 'with'),
#  (',', 'with', 'full'),
#  ('with', 'full', 'eyes'),
#  ('full', 'eyes', 'and'),
#  ('eyes', 'and', 'empty'),
#  ('and', 'empty', 'glasses'),
#  ('empty', 'glasses', ','),
#  ('glasses', ',', 'and'),
#  (',', 'and', 'in'),
#  ('and', 'in', 'not'),
#  ('in', 'not', 'altogether'),
#  ('not', 'altogether', 'unpleasant'),
#  ('altogether', 'unpleasant', 'sadness'),
#  ('unpleasant', 'sadness', '--'),
#  ('sadness', '--', 'Give'),
#  ('--', 'Give', 'it'),
#  ('Give', 'it', 'up'),
#  ('it', 'up', ','),
#  ('up', ',', 'Sub'),
#  (',', 'Sub', '-'),
#  ('Sub', '-', 'Subs'),
#  ('-', 'Subs', '!'),
#  ('Subs', '!', 'For'),
#  ('!', 'For', 'by'),
#  ('For', 'by', 'how'),
#  ('by', 'how', 'much'),
#  ('how', 'much', 'the'),
#  ('much', 'the', 'more'),
#  ('the', 'more', 'pains'),
#  ('more', 'pains', 'ye'),
#  ('pains', 'ye', 'take'),
#  ('ye', 'take', 'to'),
#  ('take', 'to', 'please'),
#  ('to', 'please', 'the'),
#  ('please', 'the', 'world'),
#  ('the', 'world', ','),
#  ('world', ',', 'by'),
#  (',', 'by', 'so'),
#  ('by', 'so', 'much'),
#  ('so', 'much', 'the'),
#  ('much', 'the', 'more'),
#  ('the', 'more', 'shall'),
#  ('more', 'shall', 'ye'),
#  ('shall', 'ye', 'for'),
#  ('ye', 'for', 'ever'),
#  ('for', 'ever', 'go'),
#  ('ever', 'go', 'thankless'),
#  ('go', 'thankless', '!'),
#  ('thankless', '!', 'Would'),
#  ('!', 'Would', 'that'),
#  ('Would', 'that', 'I'),
#  ('that', 'I', 'could'),
#  ('I', 'could', 'clear'),
#  ('could', 'clear', 'out'),
#  ('clear', 'out', 'Hampton'),
#  ('out', 'Hampton', 'Court'),
#  ('Hampton', 'Court', 'and'),
#  ('Court', 'and', 'the'),
#  ('and', 'the', 'Tuileries'),
#  ('the', 'Tuileries', 'for'),
#  ('Tuileries', 'for', 'ye'),
#  ('for', 'ye', '!'),
#  ('ye', '!', 'But'),
#  ('!', 'But', 'gulp'),
#  ('But', 'gulp', 'down'),
#  ('gulp', 'down', 'your'),
#  ('down', 'your', 'tears'),
#  ('your', 'tears', 'and'),
#  ('tears', 'and', 'hie'),
#  ('and', 'hie', 'aloft'),
#  ('hie', 'aloft', 'to'),
#  ('aloft', 'to', 'the'),
#  ('to', 'the', 'royal'),
#  ('the', 'royal', '-'),
#  ('royal', '-', 'mast'),
#  ('-', 'mast', 'with'),
#  ('mast', 'with', 'your'),
#  ('with', 'your', 'hearts'),
#  ('your', 'hearts', ';'),
#  ('hearts', ';', 'for'),
#  (';', 'for', 'your'),
#  ('for', 'your', 'friends'),
#  ('your', 'friends', 'who'),
#  ('friends', 'who', 'have'),
#  ('who', 'have', 'gone'),
#  ('have', 'gone', 'before'),
#  ('gone', 'before', 'are'),
#  ('before', 'are', 'clearing'),
#  ('are', 'clearing', 'out'),
#  ('clearing', 'out', 'the'),
#  ('out', 'the', 'seven'),
#  ('the', 'seven', '-'),
#  ('seven', '-', 'storied'),
#  ('-', 'storied', 'heavens'),
#  ('storied', 'heavens', ','),
#  ('heavens', ',', 'and'),
#  (',', 'and', 'making'),
#  ('and', 'making', 'refugees'),
#  ('making', 'refugees', 'of'),
#  ('refugees', 'of', 'long'),
#  ('of', 'long', '-'),
#  ('long', '-', 'pampered'),
#  ('-', 'pampered', 'Gabriel'),
#  ('pampered', 'Gabriel', ','),
#  ('Gabriel', ',', 'Michael'),
#  (',', 'Michael', ','),
#  ('Michael', ',', 'and'),
#  (',', 'and', 'Raphael'),
#  ('and', 'Raphael', ','),
#  ('Raphael', ',', 'against'),
#  (',', 'against', 'your'),
#  ('against', 'your', 'coming'),
#  ('your', 'coming', '.'),
#  ('coming', '.', 'Here'),
#  ('.', 'Here', 'ye'),
#  ('Here', 'ye', 'strike'),
#  ('ye', 'strike', 'but'),
#  ('strike', 'but', 'splintered'),
#  ('but', 'splintered', 'hearts'),
#  ('splintered', 'hearts', 'together'),
#  ('hearts', 'together', '--'),
#  ('together', '--', 'there'),
#  ('--', 'there', ','),
#  ('there', ',', 'ye'),
#  (',', 'ye', 'shall'),
#  ('ye', 'shall', 'strike'),
#  ('shall', 'strike', 'unsplinterable'),
#  ('strike', 'unsplinterable', 'glasses'),
#  ('unsplinterable', 'glasses', '!'),
#  ('glasses', '!', 'EXTRACTS'),
#  ('!', 'EXTRACTS', '.'),
#  ('EXTRACTS', '.', '"'),
#  ('.', '"', 'And'),
#  ('"', 'And', 'God'),
#  ('And', 'God', 'created'),
#  ('God', 'created', 'great'),
#  ('created', 'great', 'whales'),
#  ('great', 'whales', '."'),
#  ('whales', '."', '--'),
#  ('."', '--', 'GENESIS'),
#  ('--', 'GENESIS', '.'),
#  ('GENESIS', '.', '"'),
#  ('.', '"', 'Leviathan'),
#  ('"', 'Leviathan', 'maketh'),
#  ('Leviathan', 'maketh', 'a'),
#  ('maketh', 'a', 'path'),
#  ('a', 'path', 'to'),
#  ('path', 'to', 'shine'),
#  ('to', 'shine', 'after'),
#  ('shine', 'after', 'him'),
#  ('after', 'him', ';'),
#  ('him', ';', 'One'),
#  (';', 'One', 'would'),
#  ('One', 'would', 'think'),
#  ('would', 'think', 'the'),
#  ('think', 'the', 'deep'),
#  ('the', 'deep', 'to'),
#  ('deep', 'to', 'be'),
#  ('to', 'be', 'hoary'),
#  ('be', 'hoary', '."'),
#  ('hoary', '."', '--'),
#  ('."', '--', 'JOB'),
#  ('--', 'JOB', '.'),
#  ('JOB', '.', '"'),
#  ('.', '"', 'Now'),
#  ('"', 'Now', 'the'),
#  ('Now', 'the', 'Lord'),
#  ('the', 'Lord', 'had'),
#  ('Lord', 'had', 'prepared'),
#  ('had', 'prepared', 'a'),
#  ('prepared', 'a', 'great'),
#  ('a', 'great', 'fish'),
#  ('great', 'fish', 'to'),
#  ('fish', 'to', 'swallow'),
#  ('to', 'swallow', 'up'),
#  ('swallow', 'up', 'Jonah'),
#  ('up', 'Jonah', '."'),
#  ('Jonah', '."', '--'),
#  ('."', '--', 'JONAH'),
#  ('--', 'JONAH', '.'),
#  ('JONAH', '.', '"'),
#  ('.', '"', 'There'),
#  ('"', 'There', 'go'),
#  ('There', 'go', 'the'),
#  ('go', 'the', 'ships'),
#  ('the', 'ships', ';'),
#  ('ships', ';', 'there'),
#  (';', 'there', 'is'),
#  ('there', 'is', 'that'),
#  ('is', 'that', 'Leviathan'),
#  ('that', 'Leviathan', 'whom'),
#  ('Leviathan', 'whom', 'thou'),
#  ('whom', 'thou', 'hast'),
#  ('thou', 'hast', 'made'),
#  ('hast', 'made', 'to'),
#  ('made', 'to', 'play'),
#  ('to', 'play', 'therein'),
#  ('play', 'therein', '."'),
#  ('therein', '."', '--'),
#  ('."', '--', 'PSALMS'),
#  ('--', 'PSALMS', '.'),
#  ('PSALMS', '.', '"'),
#  ('.', '"', 'In'),
#  ('"', 'In', 'that'),
#  ('In', 'that', 'day'),
#  ('that', 'day', ','),
#  ('day', ',', 'the'),
#  (',', 'the', 'Lord'),
#  ('the', 'Lord', 'with'),
#  ('Lord', 'with', 'his'),
#  ('with', 'his', 'sore'),
#  ('his', 'sore', ','),
#  ('sore', ',', 'and'),
#  (',', 'and', 'great'),
#  ('and', 'great', ','),
#  ('great', ',', 'and'),
#  (',', 'and', 'strong'),
#  ('and', 'strong', 'sword'),
#  ('strong', 'sword', ','),
#  ('sword', ',', 'shall'),
#  (',', 'shall', 'punish'),
#  ('shall', 'punish', 'Leviathan'),
#  ('punish', 'Leviathan', 'the'),
#  ('Leviathan', 'the', 'piercing'),
#  ('the', 'piercing', 'serpent'),
#  ('piercing', 'serpent', ','),
#  ('serpent', ',', 'even'),
#  (',', 'even', 'Leviathan'),
#  ('even', 'Leviathan', 'that'),
#  ('Leviathan', 'that', 'crooked'),
#  ('that', 'crooked', 'serpent'),
#  ('crooked', 'serpent', ';'),
#  ('serpent', ';', 'and'),
#  (';', 'and', 'he'),
#  ('and', 'he', 'shall'),
#  ('he', 'shall', 'slay'),
#  ('shall', 'slay', 'the'),
#  ('slay', 'the', 'dragon'),
#  ('the', 'dragon', 'that'),
#  ('dragon', 'that', 'is'),
#  ('that', 'is', 'in'),
#  ('is', 'in', 'the'),
#  ('in', 'the', 'sea'),
#  ('the', 'sea', '."'),
#  ('sea', '."', '--'),
#  ('."', '--', 'ISAIAH'),
#  ('--', 'ISAIAH', '"'),
#  ('ISAIAH', '"', 'And'),
#  ('"', 'And', 'what'),
#  ('And', 'what', 'thing'),
#  ('what', 'thing', 'soever'),
#  ('thing', 'soever', 'besides'),
#  ('soever', 'besides', 'cometh'),
#  ('besides', 'cometh', 'within'),
#  ('cometh', 'within', 'the'),
#  ('within', 'the', 'chaos'),
#  ('the', 'chaos', 'of'),
#  ('chaos', 'of', 'this'),
#  ('of', 'this', 'monster'),
#  ('this', 'monster', "'"),
#  ('monster', "'", 's'),
#  ("'", 's', 'mouth'),
#  ('s', 'mouth', ','),
#  ('mouth', ',', 'be'),
#  (',', 'be', 'it'),
#  ('be', 'it', 'beast'),
#  ('it', 'beast', ','),
#  ('beast', ',', 'boat'),
#  (',', 'boat', ','),
#  ('boat', ',', 'or'),
#  (',', 'or', 'stone'),
#  ('or', 'stone', ','),
#  ('stone', ',', 'down'),
#  (',', 'down', 'it'),
#  ('down', 'it', 'goes'),
#  ('it', 'goes', 'all'),
#  ('goes', 'all', 'incontinently'),
#  ('all', 'incontinently', 'that'),
#  ('incontinently', 'that', 'foul'),
#  ('that', 'foul', 'great'),
#  ('foul', 'great', 'swallow'),
#  ('great', 'swallow', 'of'),
#  ('swallow', 'of', 'his'),
#  ('of', 'his', ','),
#  ('his', ',', 'and'),
#  (',', 'and', 'perisheth'),
#  ('and', 'perisheth', 'in'),
#  ('perisheth', 'in', 'the'),
#  ('in', 'the', 'bottomless'),
#  ('the', 'bottomless', 'gulf'),
#  ('bottomless', 'gulf', 'of'),
#  ('gulf', 'of', 'his'),
#  ('of', 'his', 'paunch'),
#  ('his', 'paunch', '."'),
#  ('paunch', '."', '--'),
#  ('."', '--', 'HOLLAND'),
#  ('--', 'HOLLAND', "'"),
#  ('HOLLAND', "'", 'S'),
#  ("'", 'S', 'PLUTARCH'),
#  ('S', 'PLUTARCH', "'"),
#  ('PLUTARCH', "'", 'S'),
#  ("'", 'S', 'MORALS'),
#  ('S', 'MORALS', '.'),
#  ('MORALS', '.', '"'),
#  ('.', '"', 'The'),
#  ('"', 'The', 'Indian'),
#  ('The', 'Indian', 'Sea'),
#  ('Indian', 'Sea', 'breedeth'),
#  ('Sea', 'breedeth', 'the'),
#  ('breedeth', 'the', 'most'),
#  ('the', 'most', 'and'),
#  ('most', 'and', 'the'),
#  ('and', 'the', 'biggest'),
#  ('the', 'biggest', 'fishes'),
#  ('biggest', 'fishes', 'that'),
#  ('fishes', 'that', 'are'),
#  ('that', 'are', ':'),
#  ('are', ':', 'among'),
#  (':', 'among', 'which'),
#  ('among', 'which', 'the'),
#  ('which', 'the', 'Whales'),
#  ('the', 'Whales', 'and'),
#  ('Whales', 'and', 'Whirlpooles'),
#  ('and', 'Whirlpooles', 'called'),
#  ('Whirlpooles', 'called', 'Balaene'),
#  ('called', 'Balaene', ','),
#  ('Balaene', ',', 'take'),
#  (',', 'take', 'up'),
#  ('take', 'up', 'as'),
#  ('up', 'as', 'much'),
#  ('as', 'much', 'in'),
#  ('much', 'in', 'length'),
#  ('in', 'length', 'as'),
#  ('length', 'as', 'four'),
#  ('as', 'four', 'acres'),
#  ('four', 'acres', 'or'),
#  ('acres', 'or', 'arpens'),
#  ('or', 'arpens', 'of'),
#  ('arpens', 'of', 'land'),
#  ('of', 'land', '."'),
#  ('land', '."', '--'),
#  ('."', '--', 'HOLLAND'),
#  ('--', 'HOLLAND', "'"),
#  ('HOLLAND', "'", 'S'),
#  ("'", 'S', 'PLINY'),
#  ('S', 'PLINY', '.'),
#  ('PLINY', '.', '"'),
#  ('.', '"', 'Scarcely'),
#  ('"', 'Scarcely', 'had'),
#  ('Scarcely', 'had', 'we'),
#  ('had', 'we', 'proceeded'),
#  ('we', 'proceeded', 'two'),
#  ('proceeded', 'two', 'days'),
#  ('two', 'days', 'on'),
#  ('days', 'on', 'the'),
#  ('on', 'the', 'sea'),
#  ('the', 'sea', ','),
#  ('sea', ',', 'when'),
#  (',', 'when', 'about'),
#  ('when', 'about', 'sunrise'),
#  ('about', 'sunrise', 'a'),
#  ('sunrise', 'a', 'great'),
#  ('a', 'great', 'many'),
#  ('great', 'many', 'Whales'),
#  ('many', 'Whales', 'and'),
#  ('Whales', 'and', 'other'),
#  ('and', 'other', 'monsters'),
#  ('other', 'monsters', 'of'),
#  ('monsters', 'of', 'the'),
#  ('of', 'the', 'sea'),
#  ('the', 'sea', ','),
#  ('sea', ',', 'appeared'),
#  (',', 'appeared', '.'),
#  ('appeared', '.', 'Among'),
#  ('.', 'Among', 'the'),
#  ('Among', 'the', 'former'),
#  ('the', 'former', ','),
#  ('former', ',', 'one'),
#  (',', 'one', 'was'),
#  ('one', 'was', 'of'),
#  ('was', 'of', 'a'),
#  ('of', 'a', 'most'),
#  ('a', 'most', 'monstrous'),
#  ('most', 'monstrous', 'size'),
#  ('monstrous', 'size', '.'),
#  ('size', '.', '...'),
#  ('.', '...', 'This'),
#  ('...', 'This', 'came'),
#  ('This', 'came', 'towards'),
#  ('came', 'towards', 'us'),
#  ('towards', 'us', ','),
#  ('us', ',', 'open'),
#  (',', 'open', '-'),
#  ('open', '-', 'mouthed'),
#  ('-', 'mouthed', ','),
#  ('mouthed', ',', 'raising'),
#  (',', 'raising', 'the'),
#  ('raising', 'the', 'waves'),
#  ('the', 'waves', 'on'),
#  ('waves', 'on', 'all'),
#  ('on', 'all', 'sides'),
#  ('all', 'sides', ','),
#  ('sides', ',', 'and'),
#  (',', 'and', 'beating'),
#  ('and', 'beating', 'the'),
#  ('beating', 'the', 'sea'),
#  ('the', 'sea', 'before'),
#  ('sea', 'before', 'him'),
#  ('before', 'him', 'into'),
#  ('him', 'into', 'a'),
#  ('into', 'a', 'foam'),
#  ('a', 'foam', '."'),
#  ('foam', '."', '--'),
#  ('."', '--', 'TOOKE'),
#  ('--', 'TOOKE', "'"),
#  ('TOOKE', "'", 'S'),
#  ("'", 'S', 'LUCIAN'),
#  ('S', 'LUCIAN', '.'),
#  ('LUCIAN', '.', '"'),
#  ('.', '"', 'THE'),
#  ('"', 'THE', 'TRUE'),
#  ('THE', 'TRUE', 'HISTORY'),
#  ('TRUE', 'HISTORY', '."'),
#  ('HISTORY', '."', '"'),
#  ('."', '"', 'He'),
#  ('"', 'He', 'visited'),
#  ('He', 'visited', 'this'),
#  ('visited', 'this', 'country'),
#  ('this', 'country', 'also'),
#  ('country', 'also', 'with'),
#  ('also', 'with', 'a'),
#  ('with', 'a', 'view'),
#  ('a', 'view', 'of'),
#  ('view', 'of', 'catching'),
#  ('of', 'catching', 'horse'),
#  ('catching', 'horse', '-'),
#  ('horse', '-', 'whales'),
#  ('-', 'whales', ','),
#  ('whales', ',', 'which'),
#  (',', 'which', 'had'),
#  ('which', 'had', 'bones'),
#  ('had', 'bones', 'of'),
#  ('bones', 'of', 'very'),
#  ('of', 'very', 'great'),
#  ('very', 'great', 'value'),
#  ('great', 'value', 'for'),
#  ('value', 'for', 'their'),
#  ('for', 'their', 'teeth'),
#  ('their', 'teeth', ','),
#  ('teeth', ',', 'of'),
#  (',', 'of', 'which'),
#  ('of', 'which', 'he'),
#  ('which', 'he', 'brought'),
#  ('he', 'brought', 'some'),
#  ('brought', 'some', 'to'),
#  ('some', 'to', 'the'),
#  ('to', 'the', 'king'),
#  ('the', 'king', '.'),
#  ('king', '.', '...'),
#  ('.', '...', 'The'),
#  ('...', 'The', 'best'),
#  ('The', 'best', 'whales'),
#  ('best', 'whales', 'were'),
#  ('whales', 'were', 'catched'),
#  ('were', 'catched', 'in'),
#  ('catched', 'in', 'his'),
#  ('in', 'his', 'own'),
#  ('his', 'own', 'country'),
#  ('own', 'country', ','),
#  ('country', ',', 'of'),
#  (',', 'of', 'which'),
#  ('of', 'which', 'some'),
#  ('which', 'some', 'were'),
#  ('some', 'were', 'forty'),
#  ('were', 'forty', '-'),
#  ('forty', '-', 'eight'),
#  ('-', 'eight', ','),
#  ('eight', ',', 'some'),
#  (',', 'some', 'fifty'),
#  ('some', 'fifty', 'yards'),
#  ('fifty', 'yards', 'long'),
#  ('yards', 'long', '.'),
#  ('long', '.', 'He'),
#  ('.', 'He', 'said'),
#  ('He', 'said', 'that'),
#  ...]

# %%
text1.count('a')
# Out:
# 4569

# %%
text1.collocations()
# Out:
# Sperm Whale; Moby Dick; White Whale; old man; Captain Ahab; sperm
# whale; Right Whale; Captain Peleg; New Bedford; Cape Horn; cried Ahab;
# years ago; lower jaw; never mind; Father Mapple; cried Stubb; chief
# mate; white whale; ivory leg; one hand

# %%
text1.name
# Out:
# 'Moby Dick by Herman Melville 1851'
