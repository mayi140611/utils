# %% [markdown]
# https://blog.csdn.net/flyinglittlepig/article/details/71598144

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import myrnn
import numpy as np

# %%
np.random.uniform()
np.zeros()

# %%
sum(myrnn.softmax([1,2,3,4]))
# Out:
# 1.0

# %%
with open('tangshi.txt', 'r') as f:
    s = f.readlines()
    s = [i.strip() for i in s]
    print(s[:2])
# Out:
# ['第一卷李世民\n', '\u3000\u3000◎卷.1【帝京篇十首】李世民\n']

# %%
with open('tangshi.txt', 'r') as f:
    s = f.readlines()
    s = [i.strip() for i in s if i.strip() and not i.strip().startswith('第') and not i.strip().startswith('◎')]
    print(s[:2])
# Out:
# ['秦川雄帝宅，函谷壮皇居。绮殿千寻起，离宫百雉馀。', '连薨遥接汉，飞观迥凌虚。云日隐层阙，风烟出绮疏。']

# %%
'%s %s %s' % ('start_token', list('sent'), 'end_token')
# Out:
# "start_token ['s', 'e', 'n', 't'] end_token"
